# %%
import os
import time
import requests
import base64
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def download_image(img_data, save_path):
    try:
        with open(save_path, 'wb') as f:
            f.write(img_data)
        print(f"Đã tải xuống hình ảnh thành công và lưu vào '{save_path}'")
    except Exception as e:
        print(f"Lỗi khi tải xuống hình ảnh: {e}")

def scrape_images_from_google(url, max_images=500):
    # Khởi tạo trình duyệt
    driver = webdriver.Chrome()

    # Mở trang web
    driver.get(url)

    # Lặp để cuộn trang và tải thêm ảnh
    for i in range(5):  # Cuộn trang 5 lần,
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Đợi để trang cuộn và ảnh tải thêm

    # Trích xuất HTML từ trang web sau khi cuộn
    html = driver.page_source

    # Sử dụng BeautifulSoup để phân tích HTML
    soup = BeautifulSoup(html, "html.parser")

    # Tìm tất cả các thẻ <img> trong HTML
    images = soup.find_all("img", class_="rg_i")

    # Tạo thư mục để lưu trữ ảnh (nếu chưa tồn tại)
    os.makedirs("images", exist_ok=True)

    # Số lượng ảnh tải về tối đa
    downloaded_images = 0

    # Lặp qua danh sách các hình ảnh và tải chúng về
    for img in images:
        img_url = img.get("src")
        if img_url:
            try:
                if "base64," in img_url:
                    img_data = base64.b64decode(img_url.split("base64,")[1])
                else:
                    response = requests.get(img_url)
                    response.raise_for_status()  # Xác nhận không có lỗi khi yêu cầu
                    img_data = response.content
                img_filename = os.path.join("images", f"image_{downloaded_images}.jpg")
                download_image(img_data, img_filename)
                downloaded_images += 1
                if downloaded_images >= max_images:
                    break
            except requests.exceptions.RequestException as e:
                print(f"Failed to download {img_url}: {str(e)}")

    # Đóng trình duyệt
    driver.quit()

# Danh sách các URL của trang web bạn muốn tìm kiếm
urls_to_scrape = [
    'https://www.google.com/search?sca_esv=b9615c6636962dbd&sxsrf=ACQVn08XCnWRi4kYPhDM3p7HXmCwHVBbYg:1708456506946&q=%E1%BA%A3nh+x%E1%BA%A3+s%C3%BAng&tbm=isch&source=lnms&sa=X&ved=2ahUKEwivtte50LqEAxXV4TgGHeQ0DxoQ0pQJegQIDBAB&biw=1536&bih=730&dpr=1.25',
    'https://www.google.com/search?sca_esv=b9615c6636962dbd&sxsrf=ACQVn0-8cWSckfTI3XBcpy52ETDBMAwmuw:1708459535597&q=%E1%BA%A3nh+x%E1%BA%A3+s%C3%BAng+kh%E1%BB%A7ng+b%E1%BB%91&tbm=isch&source=lnms&sa=X&ved=2ahUKEwiZ1O3d27qEAxXcqWMGHfEBA4gQ0pQJegQIDhAB&biw=1536&bih=730&dpr=1.25',
]

# Lặp qua danh sách các URL và thực hiện quy trình tải ảnh
for url in urls_to_scrape:
    scrape_images_from_google(url)
# Out:
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_0.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_1.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_2.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_3.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_4.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_5.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_6.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_7.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_8.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_9.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_10.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_11.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_12.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_13.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_14.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_15.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_16.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_17.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_18.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_19.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_20.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_21.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_22.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_23.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_24.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_25.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_26.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_27.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_28.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_29.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_30.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_31.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_32.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_33.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_34.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_35.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_36.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_37.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_38.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_39.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_40.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image_41.jpg'
# Đã tải xuống hình ảnh thành công và lưu vào 'images\image